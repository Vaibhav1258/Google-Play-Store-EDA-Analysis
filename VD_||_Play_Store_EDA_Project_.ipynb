# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhav1258/Google-Play-Store-EDA-Analysis/blob/main/VD_%7C%7C_Play_Store_EDA_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -----
#
#
# -----
#
#
#
# # **Project Name**    - Play Store App Review Analysis  ![google-play-png-logo-3783.png](data:image/png;base64,...)
#
#
#
#
# -----
# -----

# %%
'''from PIL import Image
from google.colab import files
uploaded = files.upload()
img = Image.open("/content/google-play-png-logo-3783.png")
img.show()'''

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Team Member 1 -** Vaibhav Dwivedi
# ##### **Team Member 2 -** Shashank Rajput
# ##### **Team Member 3 -** Aman Singh
# ##### **Team Member 4 -** Amit Kumar
# ##### **Team Member 5 -** Bhawesh Chandravanshi

# %% [markdown]
# # **Project Summary -**
#
# #Our project based on EDA (Exploratort Data Analysis) type and we are using Google Play Store App Review dataset to EDA.
# #Here we are using Python language to do operation and also import some important libraries such as Pandas for data analysis and Matplotlib for data visulization etc. Our main Objective is to discover key factors reposible for App engagement and success.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [Github link](https://github.com/Vaibhav1258/Google-Play-Store-EDA-Analysis)

# %% [markdown]
# # ***Let's start our analysis now***

# %% [markdown]
# **First of all we are importing all libraries which is helpfull for our analysis and data cleaning**

# %%
import numpy as np                              # for numerical calculations
import pandas as pd                             # for data cleaning
import matplotlib.pyplot as plt                 # for data visualisation
# %matplotlib inline                
import seaborn as sns                           # it's also a part of matplotlibbut it's use for specific graph and plots

# %% [markdown]
# #**1. Here we mounting colab from drive and reading our dataset/dataframe**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Here we read our Play store dataset/dataframe
play_df = pd.read_csv('/content/drive/MyDrive/EDA PROJECT/Play Store Data.csv')

# %%
play_df.head()

# %%
play_df.tail()

# %%
# here we checking info of our data

play_df.info()

# %% [markdown]
# *  Now here we can see some null values in our given data so now we fill our null values from (zero/mean/median).

# %%
# Here we check how many null values in our dataset

play_df.isnull().sum()

# %% [markdown]
# Now here we can see that there are null values in rating,type,content rating,curr version and android version.

# %%
# checking the shape of our data

play_df.shape

# %%
# we use the column cmd for checking all names of column
play_df.columns

# %%
# here we loading user review CSV dataset
review_df = pd.read_csv('/content/drive/MyDrive/EDA PROJECT/User Reviews.csv')

# %%
# here we checking info of our data
review_df.info()

# %% [markdown]
# Now here we can see that there are null values in rating,type,content rating,curr version and android version.

# %%
# checking the shape of our data
review_df.shape

# %%
review_df.head()

# %%
review_df.tail()

# %%
# we use the column cmd for checking all names of column
review_df.columns

# %% [markdown]
# #**2. Now we can start Data Cleaning**

# %% [markdown]
# **First of all We create a copy of both dataset for perform multiple visualisation and analysis**

# %%
# We create a copy of first dataset for perform multiple visualisation and analysis

df_1= play_df.copy()
df_1

# %%
df_2 = review_df.copy()
df_2

# %% [markdown]
# **Now here we can check null values in both datasets/ dataframes**

# %%
# Here we check how many null values in our dataset
df_1.isnull().sum()

# %% [markdown]
# Now here we can see that there are null values in rating,type,content rating,curr version and android version.

# %%
df_2.isnull().sum()

# %% [markdown]
# Now here we can see that there are null values in Translated_Review,Sentiment,Sentiment_Polarity,Sentiment_Subjectivity.

# %% [markdown]
# **Now replace null values with zeros and mean values**

# %%
# For first dataset
df_1.fillna(0, inplace=True)

# For second dataset
df_2.fillna((df_2.mean()), inplace=True) #its for only numaric values

# %%
df_2.fillna(0, inplace=True)

# %%
#because of previous command our null values is replace with zero and now checking our both datasets

df_1.isnull().sum()

# %%
df_1.info()

# %%
df_1.boxplot()

# %%
df_1[df_1.Rating>5]

# %%
df_1.drop(10472, inplace = True)

# %%
df_1[10470:10475]

# %%
df_1.boxplot()

# %%
df_1.hist()

# %%
df_1.shape
# Out:
# (10840, 13)

# %%
df_2.isnull().sum()

# %%
df_2.info()

# %%
df_2.shape

# %% [markdown]
# We have fill the dataset with zeros at the place of nan values for better visualization and analysis.

# %%
df_2.boxplot()

# %%
df_2.hist()

# %%
df_2
